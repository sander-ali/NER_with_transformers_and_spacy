# %%
#import necessary packages
#Spacy's named entity recognition has been trained on the OntoNotes 5 Corpus
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
import utils

# %%
nlp = en_core_web_sm.load()

# %%
#just an example as to how we can apply spacy for nlp
doc = nlp('European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices')
print([(X.text, X.label_) for X in doc.ents])
# Out:
# [('European', 'NORP'), ('Google a record $5.1 billion', 'ORG'), ('Wednesday', 'DATE')]

# %%
#using BILUO Tagging scheme
#B --> Begin
#I --> In
#L --> Last
#U --> Unit
#O --> Out
print([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(European, 'B', 'NORP'), (authorities, 'O', ''), (fined, 'O', ''), (Google, 'B', 'ORG'), (a, 'I', 'ORG'), (record, 'I', 'ORG'), ($, 'I', 'ORG'), (5.1, 'I', 'ORG'), (billion, 'I', 'ORG'), (on, 'O', ''), (Wednesday, 'B', 'DATE'), (for, 'O', ''), (abusing, 'O', ''), (its, 'O', ''), (power, 'O', ''), (in, 'O', ''), (the, 'O', ''), (mobile, 'O', ''), (phone, 'O', ''), (market, 'O', ''), (and, 'O', ''), (ordered, 'O', ''), (the, 'O', ''), (company, 'O', ''), (to, 'O', ''), (alter, 'O', ''), (its, 'O', ''), (practices, 'O', '')]

# %%
#Extracting named entity from an article
dawn_bb = utils.url_to_string('https://www.dawn.com/news/1689940/a-stable-tenure')
article = nlp(dawn_bb)
len(article.ents)
#185 entities in this article with 10 unique labels
# Out:
# 185

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'PERSON': 32,
#          'DATE': 62,
#          'ORG': 30,
#          'FAC': 6,
#          'LAW': 4,
#          'NORP': 8,
#          'GPE': 19,
#          'CARDINAL': 20,
#          'TIME': 1,
#          'ORDINAL': 1,
#          'MONEY': 1,
#          'PRODUCT': 1})

# %%
#Following are the three most frequent tokens
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('2022', 9), ('Pakistan', 7), ('May 16, 2022', 3)]

# %%
#Randomly select one sentence to analyze
sentences = [x for x in article.sents]
print(sentences[20])
# Out:
# Only four democratically elected leaders have ever come close to that mark in our 75-year history.

# %%
#displacy.render generates the raw markup
displacy.render(nlp(str(sentences[20])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Only four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  democratically elected leaders have ever come close to that mark in our
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     75-year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  history.</div></span>

# %%
#displacy visualizer helps you to analyze the dependencies
displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="af53d1137cd04ee1ae2cbeee25f48b9b-0" class="displacy" width="2090" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Only</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">four</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">democratically</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">elected</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">leaders</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">ever</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">come</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">close</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">mark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">our</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">75-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">year</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">history.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af53d1137cd04ee1ae2cbeee25f48b9b-0-0" stroke-width="2px" d="M70,182.0 C70,122.0 160.0,122.0 160.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af53d1137cd04ee1ae2cbeee25f48b9b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af53d1137cd04ee1ae2cbeee25f48b9b-0-1" stroke-width="2px" d="M190,182.0 C190,62.0 525.0,62.0 525.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af53d1137cd04ee1ae2cbeee25f48b9b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af53d1137cd04ee1ae2cbeee25f48b9b-0-2" stroke-width="2px" d="M310,182.0 C310,122.0 400.0,122.0 400.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af53d1137cd04ee1ae2cbeee25f48b9b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,184.0 L302,172.0 318,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af53d1137cd04ee1ae2cbeee25f48b9b-0-3" stroke-width="2px" d="M430,182.0 C430,122.0 520.0,122.0 520.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af53d1137cd04ee1ae2cbeee25f48b9b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,184.0 L422,172.0 438,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af53d1137cd04ee1ae2cbeee25f48b9b-0-4" stroke-width="2px" d="M550,182.0 C550,2.0 890.0,2.0 890.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af53d1137cd04ee1ae2cbeee25f48b9b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af53d1137cd04ee1ae2cbeee25f48b9b-0-5" stroke-width="2px" d="M670,182.0 C670,62.0 885.0,62.0 885.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af53d1137cd04ee1ae2cbeee25f48b9b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,184.0 L662,172.0 678,172.0" fill="currentColor"/>

# %%
#extract part-of-speech and lemmatize this sentence
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[20])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('democratically', 'ADV', 'democratically'),
#  ('elected', 'VERB', 'elect'),
#  ('leaders', 'NOUN', 'leader'),
#  ('come', 'VERB', 'come'),
#  ('close', 'ADV', 'close'),
#  ('mark', 'NOUN', 'mark'),
#  ('75', 'NUM', '75'),
#  ('year', 'NOUN', 'year'),
#  ('history', 'NOUN', 'history')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[20])).ents])
# Out:
# {'Only four': 'CARDINAL', '75-year': 'DATE'}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[20]])
# Out:
# [(Only, 'B', 'CARDINAL'), (four, 'I', 'CARDINAL'), (democratically, 'O', ''), (elected, 'O', ''), (leaders, 'O', ''), (have, 'O', ''), (ever, 'O', ''), (come, 'O', ''), (close, 'O', ''), (to, 'O', ''), (that, 'O', ''), (mark, 'O', ''), (in, 'O', ''), (our, 'O', ''), (75, 'B', 'DATE'), (-, 'I', 'DATE'), (year, 'I', 'DATE'), (history, 'O', ''), (., 'O', '')]

# %%
#Visualize the entity of an entire article
displacy.render(article, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">                              A stable tenure - Newspaper - DAWN.COM                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 EPAPER                                 LIVE TV                                 DAWNNEWS URDU                                 Images                                 Herald
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aurora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# CityFM89                                 Teeli
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Advertise
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# Events                                 /Supplements                                 Classifieds                                 Obituaries                                                                                                                               DAWN.COM
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's Paper |
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 17, 2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#                                                                                                                                     Home           Latest
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pakistan           Business           Opinion           Culture           Sport           Magazines           World           Tech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# Prism           Popular           Multimedia           Archive           In Depth                                                                                                                                                                                                                                                                                                                                                                                                             Home           Latest
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pakistan           Business           Opinion           Culture           Sport           Magazines           World           Tech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# Prism           Popular           Multimedia           Archive           In Depth                                                                           Search                                                                                                                                                                                                                                                                                                                                                   Advertisement                                                          Advertisement                                                          Advertisement                                                          Advertisement                                                                                                                                               A stable tenure
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tasneem Noorani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# Published
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 16, 2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#   -           Updated
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 16, 2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#          07:55am                                                                                                                     1                                The writer is a former civil servant.                                              WE have a situation on hand in the country, caused by the premature departure of a prime minister in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     44 months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  rather than
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 60 months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  stipulated in the
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Constitution
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# . His early exit, forced by the opposition and encouraged by the establishment’s new policy of staying ‘apolitical’, now poses an existential threat to the country as it has triggered grave economic uncertainty and invited a strong negative reaction from large sections of the public. The untimely fall of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pakistani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  governme­nts is nothing new. Research reveals that the maximum tenure a PM has held in
# <mark class="entity" style="
